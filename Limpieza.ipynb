# %% [markdown]
# <a href="https://colab.research.google.com/github/SamuelVelez-G/Analisis-de-siniestros-viales-Medellin/blob/main/Limpieza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importar librerias de analitica de datos
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('https://github.com/juanpa48/Proyecto_accidentalidad/raw/refs/heads/main/Mede_14-21part1.csv', sep=';', encoding='latin1', engine='python', on_bad_lines='skip')
df2 = pd.read_csv('https://github.com/juanpa48/Proyecto_accidentalidad/raw/refs/heads/main/Mede_14-21part2.csv', sep=';', encoding='latin1', engine='python', on_bad_lines='skip')

df = pd.concat([df1, df2], ignore_index=True)

df
# Out:
#        Gravedad_victima Fecha_incidente Hora_incidente Clase_incidente  \
# 0               Heridos       1/01/2014        0:15:00            Otro
# 1               Heridos       1/01/2014        0:30:00       Atropello
# 2               Heridos       1/01/2014        0:30:00       Atropello
# 3               Heridos       1/01/2014        0:37:00       Atropello
# 4               Heridos       1/01/2014        0:37:00       Atropello
# ...                 ...             ...            ...             ...
# 235838          Heridos      30/09/2021       22:00:00            Otro
# 235839          Heridos      30/09/2021       22:00:00            Otro
# 235840          Heridos      30/09/2021       22:00:00  Caida Ocupante
# 235841          Heridos      30/09/2021       23:00:00       Atropello
# 235842          Heridos      30/09/2021       23:00:00            Otro
#
#        Direccion_incidente Sexo Edad                    Condicion  Mes   Dia  \
# ...
